# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#             Date   Time Citation No   Offense             Detailed Reason  \
# 0     04/01/2021  00:00    T2659741    90:9D-      EXCESSIVE WINDOWS TINT
# 1     04/01/2021  17:25    T2659785    90:9D-      EXCESSIVE WINDOWS TINT
# 2     04/01/2021  17:41    T2659786    90:9D-      EXCESSIVE WINDOWS TINT
# 3     04/01/2021  18:55    T2659787    90:9D-      EXCESSIVE WINDOWS TINT
# 4     04/01/2021  19:03    T2659806  90:13B-B  ELECTRONIC DEVICE WHILE OP
# ...          ...    ...         ...       ...                         ...
# 1491  04/30/2021  17:24    T2089018  90:13B-B  ELECTRONIC DEVICE WHILE OP
# 1492  04/30/2021  17:43    T2089019   90:16A-   IDLE ENGINE STOPPED MV OV
# 1493  04/30/2021  20:12    T2658311    90:7-A         DEFECTIVE EQUIPMENT
# 1494  04/30/2021  20:12    T2658311     90:6-       FAIL TO DISPLAY PLATE
# 1495  04/30/2021  20:12    T2658311   90:23-A   OPERATING AFTER SUSPENSIO
#
#                    Location   Latitude  Longitude   Zipcode
# ...

# %%
labels = {}
for entry in data.iterrows():
    if entry[1][2] not in labels.keys():
        labels[entry[1][2]] = [entry[1][5],entry[1][6],entry[1][7],entry[1][8]]

# %%
labels
# Out:
# {'T2659741': ['BRIDGE / VFW', 42.6443138, -71.304718, 'MA 01852'],
#  'T2659785': ['PAWTUCKET / ARLINGTON', 42.6487907, -71.3275565, 'MA 01854'],
#  'T2659786': ['BROADWAY / LEWIS', 42.6444381, -71.3167669, 'MA 01854'],
#  'T2659787': ['ROGERS / PERRY', 42.636194, -71.2999831, 'MA 01852'],
#  'T2659806': ['BRIDGE / VFW', 42.6443138, -71.304718, 'MA 01852'],
#  'T2658073': ['ELM / CHAPEL', 42.637452, -71.3067376, 'MA 01852'],
#  'T2659788': ['0 AV', 42.6334247, -71.3161718, 'MA 01851'],
#  'T2658074': ['BRIDGE / THIRD', 42.6443138, -71.304718, 'MA 01852'],
#  'T2659169': ['GORHAM / ELM', 42.636987, -71.308926, 'MA 01852'],
#  'T2659949': ['PRINCETON / FOSTER', 42.6347698, -71.3386348, 'MA 01851'],
#  'T2658221': ['BRIDGE / VFW', 42.6443138, -71.304718, 'MA 01852'],
#  'T2659950': ['PRINCETON / FOSTER', 42.6347698, -71.3386348, 'MA 01851'],
#  'T2659951': ['PRINCETON / FOSTER', 42.6347698, -71.3386348, 'MA 01851'],
#  'T2658222': ['BRIDGE / VFW', 42.6443138, -71.304718, 'MA 01852'],
# ...
